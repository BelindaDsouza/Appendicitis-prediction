# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix

# %%
df=pd.read_excel('Appendicitis1.xlsx')

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# Assume 'X' contains your features and 'y' contains your target variable
X = df.drop(columns=['Management', 'Severity', 'Diagnosis','BMI','Length_of_Stay',
                     'Diagnosis_Presumptive','Alvarado_Score','Paedriatic_Appendicitis_Score'])  # Features
y = df['Diagnosis']  # Target variable
X = pd.get_dummies(X)  

# Select top k features using chi-square test
k = 10  # Number of features to select
chi2_selector = SelectKBest(chi2, k=k)
X_kbest = chi2_selector.fit_transform(X, y)

# Get the indices of the selected features
selected_indices = chi2_selector.get_support(indices=True)
# Get the names of the selected features
selected_features = X.columns[selected_indices]

# Print the names of the selected features
print("Selected features:")
print(selected_features)
# Out:
# Selected features:
# Index(['Sex', 'Weight', 'Migratory_Pain', 'Contralateral_Rebound_Tenderness',
#        'Nausea', 'Loss_of_Appetite', 'WBC_Count', 'Neutrophil_Percentage',
#        'Neutrophilia', 'CRP'],
#       dtype='object')

# %%
# Create a new DataFrame with selected features
df1 = df.loc[:, selected_features].copy()

# Add 'Age' and 'Height' columns to the selected DataFrame
df1['Lower_Right_Abd_Pain'] = df['Lower_Right_Abd_Pain']
df1['Body_Temperature'] = df['Body_Temperature']
df1['Age'] = df['Age']
df1['Height'] = df['Height']
df1['Diagnosis'] = df['Diagnosis']

# Display the first few rows of the new DataFrame
print(df1.head())
# Out:
#    Sex  Weight  Migratory_Pain  Contralateral_Rebound_Tenderness  Nausea  \
# 0    0    37.0               0                                 1       0
# 1    1    69.5               1                                 1       0
# 2    0    62.0               0                                 1       0
# 3    0    56.0               1                                 0       1
# 4    0    45.0               0                                 1       1
#
#    Loss_of_Appetite  WBC_Count  Neutrophil_Percentage  Neutrophilia  CRP  \
# 0                 1       7700                   68.2             0  0.0
# 1                 1       8100                   64.8             0  3.0
# 2                 0      13200                   74.8             0  3.0
# 3                 1      11400                   63.0             0  0.0
# 4                 1       8100                   44.0             0  0.0
#
#    Lower_Right_Abd_Pain  Body_Temperature  Age  Height  Diagnosis
# 0                     1              37.0   12     148          0
# 1                     1              36.9   14     147          1
# 2                     1              36.6   14     163          1
# 3                     1              36.0   16     165          1
# 4                     1              36.9   11     163          0

# %%
'''from imblearn.over_sampling import SMOTE
import pandas as pd

# Assume 'X' contains your features and 'y' contains your target variable
X = df2.drop(columns=['Diagnosis'])  # Features
y = df2['Diagnosis']  # Target variable

# Initialize SMOTE
smote = SMOTE(random_state=0)

# Perform SMOTE oversampling
X_resampled, y_resampled = smote.fit_resample(X, y)

# Print the shape of the resampled data
print("Shape of X_resampled:", X_resampled.shape)
print("Shape of y_resampled:", y_resampled.shape)'''
# Out:
# 'from imblearn.over_sampling import SMOTE\nimport pandas as pd\n\n# Assume \'X\' contains your features and \'y\' contains your target variable\nX = df2.drop(columns=[\'Diagnosis\'])  # Features\ny = df2[\'Diagnosis\']  # Target variable\n\n# Initialize SMOTE\nsmote = SMOTE(random_state=0)\n\n# Perform SMOTE oversampling\nX_resampled, y_resampled = smote.fit_resample(X, y)\n\n# Print the shape of the resampled data\nprint("Shape of X_resampled:", X_resampled.shape)\nprint("Shape of y_resampled:", y_resampled.shape)'

# %%
# Count occurrences of class 0 (non-appendicitis)
count_non_appendicitis = sum(y == 1)

# Count occurrences of class 1 (appendicitis)
count_appendicitis = sum(y == 0)

print("Number of non-appendicitis samples:", count_non_appendicitis)
print("Number of appendicitis samples:", count_appendicitis)
# Out:
# Number of non-appendicitis samples: 302
# Number of appendicitis samples: 429

# %%
from imblearn.over_sampling import SMOTE

X = df1.drop(columns=['Diagnosis'])  
y = df1['Diagnosis']  

# Count the number of samples in each class
non_appendicitis_count = np.sum(y == 1)
appendicitis_count = np.sum(y == 0)
# Desired number of rows
desired_rows = 1100

# Calculate the number of synthetic samples needed for each class
non_appendicitis_synthetic = max(desired_rows - non_appendicitis_count, 0)
appendicitis_synthetic = max(desired_rows - appendicitis_count, 0)

# Apply SMOTE with the adjusted sampling strategy
smote = SMOTE(sampling_strategy={1: non_appendicitis_synthetic, 0: appendicitis_synthetic},
              random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Check the shape of the resampled dataset
print("Shape of X_resampled:", X_resampled.shape)
print("Shape of y_resampled:", y_resampled.shape)
# Out:
# Shape of X_resampled: (1469, 14)
# Shape of y_resampled: (1469,)

# %%
# Count occurrences of class 0 (non-appendicitis)
count_non_appendicitis = sum(y_resampled == 1)

# Count occurrences of class 1 (appendicitis)
count_appendicitis = sum(y_resampled == 0)

print("Number of non-appendicitis samples:", count_non_appendicitis)
print("Number of appendicitis samples:", count_appendicitis)
# Out:
# Number of non-appendicitis samples: 798
# Number of appendicitis samples: 671

# %%
from sklearn.linear_model import LogisticRegression
# Splitting the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled,
                            y_resampled, test_size=0.2, random_state=42)

# Train a logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy*100)

# Classification report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 72.10884353741497
#               precision    recall  f1-score   support
#
#            0       0.65      0.70      0.67       121
#            1       0.78      0.73      0.76       173
#
#     accuracy                           0.72       294
#    macro avg       0.71      0.72      0.72       294
# weighted avg       0.73      0.72      0.72       294
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[ 85  36]
#  [ 46 127]]

# %%
from sklearn.svm import SVC
# Splitting the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Initialize SVM model
svm_model = SVC(kernel='linear', random_state=42)  # Linear kernel for linear SVM

# Train the model
svm_model.fit(X_train, y_train)

# Predictions on the test set
y_pred = svm_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Classification report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7448979591836735
#               precision    recall  f1-score   support
#
#            0       0.67      0.74      0.70       121
#            1       0.80      0.75      0.78       173
#
#     accuracy                           0.74       294
#    macro avg       0.74      0.74      0.74       294
# weighted avg       0.75      0.74      0.75       294

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[ 89  32]
#  [ 43 130]]

# %%
from sklearn.naive_bayes import GaussianNB

# Splitting the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Initialize Naive Bayes model
naive_bayes_model = GaussianNB()

# Train the model
naive_bayes_model.fit(X_train, y_train)

# Predictions on the test set
y_pred = naive_bayes_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy*100)

# Classification report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 73.12925170068027
#               precision    recall  f1-score   support
#
#            0       0.69      0.63      0.66       121
#            1       0.76      0.80      0.78       173
#
#     accuracy                           0.73       294
#    macro avg       0.72      0.72      0.72       294
# weighted avg       0.73      0.73      0.73       294

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[ 76  45]
#  [ 34 139]]

# %%
from sklearn.ensemble import GradientBoostingClassifier
# Splitting the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=0)

# Initialize Gradient Boosting model
gb_model = GradientBoostingClassifier(random_state=42)

# Train the model
gb_model.fit(X_train, y_train)

# Predictions on the test set
y_pred = gb_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy*100)

# Classification report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 76.87074829931973
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73       128
#            1       0.79      0.80      0.80       166
#
#     accuracy                           0.77       294
#    macro avg       0.76      0.76      0.76       294
# weighted avg       0.77      0.77      0.77       294

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[ 93  35]
#  [ 33 133]]

# %%
from sklearn.neighbors import KNeighborsClassifier

# Splitting the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, 
                                                test_size=0.2, random_state=42)

# Initialize KNN model
knn_model = KNeighborsClassifier(n_neighbors=5)  
# Train the model
knn_model.fit(X_train, y_train)
# Predictions on the test set
y_pred = knn_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy*100)

# Classification report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 78.2312925170068
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73       121
#            1       0.81      0.83      0.82       173
#
#     accuracy                           0.78       294
#    macro avg       0.78      0.77      0.77       294
# weighted avg       0.78      0.78      0.78       294

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[ 87  34]
#  [ 30 143]]

# %%
from catboost import CatBoostClassifier
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled,
                                                    test_size=0.2, random_state=0)

# Initialize CatBoost model
catboost_model = CatBoostClassifier(iterations=1000, depth=6, learning_rate=0.1,
                                    random_state=42)

# Train the model
catboost_model.fit(X_train, y_train)  # Assuming 'Sex' is a categorical feature

# Predictions on the test set
y_pred = catboost_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy*100)
# Out:
# 0:	learn: 0.6539504	total: 601ms	remaining: 10m
# 1:	learn: 0.6108811	total: 614ms	remaining: 5m 6s
# 2:	learn: 0.5830414	total: 636ms	remaining: 3m 31s
# 3:	learn: 0.5601214	total: 664ms	remaining: 2m 45s
# 4:	learn: 0.5410271	total: 688ms	remaining: 2m 16s
# 5:	learn: 0.5237624	total: 768ms	remaining: 2m 7s
# 6:	learn: 0.5077534	total: 786ms	remaining: 1m 51s
# 7:	learn: 0.4953984	total: 868ms	remaining: 1m 47s
# 8:	learn: 0.4830125	total: 892ms	remaining: 1m 38s
# 9:	learn: 0.4724396	total: 931ms	remaining: 1m 32s
# 10:	learn: 0.4645508	total: 966ms	remaining: 1m 26s
# 11:	learn: 0.4566939	total: 988ms	remaining: 1m 21s
# 12:	learn: 0.4488684	total: 1.02s	remaining: 1m 17s
# 13:	learn: 0.4413223	total: 1.03s	remaining: 1m 12s
# 14:	learn: 0.4345914	total: 1.04s	remaining: 1m 8s
# 15:	learn: 0.4262999	total: 1.05s	remaining: 1m 4s
# 16:	learn: 0.4208980	total: 1.07s	remaining: 1m 1s
# 17:	learn: 0.4142568	total: 1.08s	remaining: 59.1s
# 18:	learn: 0.4102758	total: 1.11s	remaining: 57.5s
# 19:	learn: 0.4052570	total: 1.14s	remaining: 55.7s
# 20:	learn: 0.3993121	total: 1.15s	remaining: 53.4s
# 21:	learn: 0.3955805	total: 1.16s	remaining: 51.6s
# 22:	learn: 0.3913197	total: 1.18s	remaining: 50s
# 23:	learn: 0.3866643	total: 1.2s	remaining: 48.6s
# 24:	learn: 0.3836516	total: 1.21s	remaining: 47.1s
# 25:	learn: 0.3812814	total: 1.22s	remaining: 45.7s
# 26:	learn: 0.3767251	total: 1.24s	remaining: 44.8s
# 27:	learn: 0.3717579	total: 1.26s	remaining: 43.9s
# 28:	learn: 0.3680643	total: 1.28s	remaining: 43s
# 29:	learn: 0.3646445	total: 1.3s	remaining: 42s
# 30:	learn: 0.3609642	total: 1.32s	remaining: 41.1s
# 31:	learn: 0.3594942	total: 1.34s	remaining: 40.6s
# 32:	learn: 0.3571538	total: 1.37s	remaining: 40s
# 33:	learn: 0.3525595	total: 1.38s	remaining: 39.3s
# 34:	learn: 0.3485359	total: 1.4s	remaining: 38.7s
# 35:	learn: 0.3434919	total: 1.43s	remaining: 38.2s
# 36:	learn: 0.3413263	total: 1.44s	remaining: 37.5s
# 37:	learn: 0.3380773	total: 1.45s	remaining: 36.8s
# 38:	learn: 0.3336668	total: 1.46s	remaining: 36.1s
# 39:	learn: 0.3315267	total: 1.47s	remaining: 35.4s
# 40:	learn: 0.3281130	total: 1.49s	remaining: 34.8s
# 41:	learn: 0.3262876	total: 1.51s	remaining: 34.5s
# 42:	learn: 0.3242840	total: 1.53s	remaining: 34s
# 43:	learn: 0.3202268	total: 1.54s	remaining: 33.4s
# 44:	learn: 0.3189518	total: 1.55s	remaining: 32.8s
# 45:	learn: 0.3166583	total: 1.56s	remaining: 32.4s
# 46:	learn: 0.3157256	total: 1.57s	remaining: 31.8s
# 47:	learn: 0.3122319	total: 1.58s	remaining: 31.3s
# 48:	learn: 0.3074338	total: 1.59s	remaining: 30.8s
# 49:	learn: 0.3040456	total: 1.59s	remaining: 30.3s
# 50:	learn: 0.3012412	total: 1.6s	remaining: 29.8s
# 51:	learn: 0.2993184	total: 1.61s	remaining: 29.4s
# 52:	learn: 0.2983098	total: 1.62s	remaining: 28.9s
# 53:	learn: 0.2967335	total: 1.63s	remaining: 28.6s
# 54:	learn: 0.2946020	total: 1.64s	remaining: 28.2s
# 55:	learn: 0.2934034	total: 1.65s	remaining: 27.8s
# 56:	learn: 0.2903595	total: 1.66s	remaining: 27.4s
# 57:	learn: 0.2874731	total: 1.67s	remaining: 27.1s
# 58:	learn: 0.2849069	total: 1.68s	remaining: 26.7s
# 59:	learn: 0.2820625	total: 1.68s	remaining: 26.4s
# 60:	learn: 0.2790950	total: 1.69s	remaining: 26s
# 61:	learn: 0.2779714	total: 1.7s	remaining: 25.7s
# 62:	learn: 0.2745934	total: 1.71s	remaining: 25.4s
# 63:	learn: 0.2721008	total: 1.72s	remaining: 25.2s
# 64:	learn: 0.2697989	total: 1.74s	remaining: 25s
# 65:	learn: 0.2679589	total: 1.75s	remaining: 24.7s
# 66:	learn: 0.2662244	total: 1.76s	remaining: 24.5s
# 67:	learn: 0.2644197	total: 1.77s	remaining: 24.3s
# 68:	learn: 0.2622733	total: 1.78s	remaining: 24s
# 69:	learn: 0.2594725	total: 1.78s	remaining: 23.7s
# 70:	learn: 0.2580914	total: 1.79s	remaining: 23.5s
# 71:	learn: 0.2567143	total: 1.8s	remaining: 23.2s
# 72:	learn: 0.2557255	total: 1.82s	remaining: 23.1s
# 73:	learn: 0.2530364	total: 1.83s	remaining: 23s
# 74:	learn: 0.2515042	total: 1.85s	remaining: 22.8s
# 75:	learn: 0.2490550	total: 1.86s	remaining: 22.6s
# 76:	learn: 0.2476700	total: 1.86s	remaining: 22.4s
# 77:	learn: 0.2447523	total: 1.87s	remaining: 22.2s
# 78:	learn: 0.2422315	total: 1.88s	remaining: 21.9s
# 79:	learn: 0.2405003	total: 1.89s	remaining: 21.7s
# 80:	learn: 0.2388722	total: 1.9s	remaining: 21.5s
# 81:	learn: 0.2378300	total: 1.91s	remaining: 21.3s
# 82:	learn: 0.2359503	total: 1.91s	remaining: 21.1s
# 83:	learn: 0.2340642	total: 1.93s	remaining: 21s
# 84:	learn: 0.2330543	total: 1.94s	remaining: 20.9s
# 85:	learn: 0.2313564	total: 1.96s	remaining: 20.9s
# 86:	learn: 0.2301976	total: 1.97s	remaining: 20.7s
# 87:	learn: 0.2274152	total: 1.99s	remaining: 20.6s
# 88:	learn: 0.2259769	total: 1.99s	remaining: 20.4s
# 89:	learn: 0.2241698	total: 2.01s	remaining: 20.3s
# 90:	learn: 0.2217613	total: 2.02s	remaining: 20.2s
# 91:	learn: 0.2213035	total: 2.03s	remaining: 20s
# 92:	learn: 0.2195198	total: 2.04s	remaining: 19.9s
# 93:	learn: 0.2169236	total: 2.04s	remaining: 19.7s
# 94:	learn: 0.2155535	total: 2.05s	remaining: 19.5s
# 95:	learn: 0.2134120	total: 2.06s	remaining: 19.4s
# 96:	learn: 0.2113175	total: 2.07s	remaining: 19.3s
# 97:	learn: 0.2094766	total: 2.08s	remaining: 19.1s
# 98:	learn: 0.2070486	total: 2.09s	remaining: 19s
# 99:	learn: 0.2055907	total: 2.1s	remaining: 18.9s
# 100:	learn: 0.2027296	total: 2.1s	remaining: 18.7s
# 101:	learn: 0.2010051	total: 2.11s	remaining: 18.6s
# 102:	learn: 0.1997595	total: 2.12s	remaining: 18.5s
# 103:	learn: 0.1977748	total: 2.13s	remaining: 18.3s
# 104:	learn: 0.1974339	total: 2.14s	remaining: 18.2s
# 105:	learn: 0.1961002	total: 2.15s	remaining: 18.1s
# 106:	learn: 0.1944464	total: 2.17s	remaining: 18.1s
# 107:	learn: 0.1930124	total: 2.18s	remaining: 18s
# 108:	learn: 0.1901250	total: 2.19s	remaining: 17.9s
# 109:	learn: 0.1885508	total: 2.2s	remaining: 17.8s
# 110:	learn: 0.1880418	total: 2.21s	remaining: 17.7s
# 111:	learn: 0.1872370	total: 2.22s	remaining: 17.6s
# 112:	learn: 0.1849496	total: 2.23s	remaining: 17.5s
# 113:	learn: 0.1834141	total: 2.23s	remaining: 17.4s
# 114:	learn: 0.1819297	total: 2.24s	remaining: 17.3s
# 115:	learn: 0.1804633	total: 2.25s	remaining: 17.1s
# 116:	learn: 0.1783939	total: 2.26s	remaining: 17s
# 117:	learn: 0.1780773	total: 2.27s	remaining: 16.9s
# 118:	learn: 0.1760096	total: 2.27s	remaining: 16.8s
# 119:	learn: 0.1749976	total: 2.28s	remaining: 16.7s
# 120:	learn: 0.1731526	total: 2.29s	remaining: 16.6s
# 121:	learn: 0.1718563	total: 2.3s	remaining: 16.5s
# 122:	learn: 0.1702601	total: 2.31s	remaining: 16.4s
# 123:	learn: 0.1701491	total: 2.31s	remaining: 16.3s
# 124:	learn: 0.1687487	total: 2.32s	remaining: 16.3s
# 125:	learn: 0.1673514	total: 2.33s	remaining: 16.2s
# 126:	learn: 0.1660006	total: 2.34s	remaining: 16.1s
# 127:	learn: 0.1658871	total: 2.34s	remaining: 16s
# 128:	learn: 0.1648085	total: 2.35s	remaining: 15.9s
# 129:	learn: 0.1637334	total: 2.36s	remaining: 15.8s
# 130:	learn: 0.1624605	total: 2.37s	remaining: 15.7s
# 131:	learn: 0.1608942	total: 2.39s	remaining: 15.7s
# 132:	learn: 0.1591738	total: 2.4s	remaining: 15.7s
# 133:	learn: 0.1578528	total: 2.42s	remaining: 15.7s
# 134:	learn: 0.1559024	total: 2.45s	remaining: 15.7s
# 135:	learn: 0.1547669	total: 2.46s	remaining: 15.7s
# 136:	learn: 0.1527597	total: 2.48s	remaining: 15.6s
# 137:	learn: 0.1520697	total: 2.51s	remaining: 15.7s
# 138:	learn: 0.1516137	total: 2.53s	remaining: 15.7s
# 139:	learn: 0.1504960	total: 2.54s	remaining: 15.6s
# 140:	learn: 0.1503084	total: 2.55s	remaining: 15.5s
# 141:	learn: 0.1487121	total: 2.55s	remaining: 15.4s
# 142:	learn: 0.1477199	total: 2.56s	remaining: 15.4s
# 143:	learn: 0.1466571	total: 2.57s	remaining: 15.3s
# 144:	learn: 0.1464652	total: 2.58s	remaining: 15.2s
# 145:	learn: 0.1451600	total: 2.59s	remaining: 15.2s
# 146:	learn: 0.1436962	total: 2.61s	remaining: 15.1s
# 147:	learn: 0.1424522	total: 2.62s	remaining: 15.1s
# 148:	learn: 0.1407701	total: 2.63s	remaining: 15s
# 149:	learn: 0.1395038	total: 2.64s	remaining: 15s
# 150:	learn: 0.1381356	total: 2.65s	remaining: 14.9s
# 151:	learn: 0.1379525	total: 2.66s	remaining: 14.8s
# 152:	learn: 0.1368825	total: 2.67s	remaining: 14.8s
# 153:	learn: 0.1362356	total: 2.68s	remaining: 14.7s
# 154:	learn: 0.1354688	total: 2.69s	remaining: 14.6s
# 155:	learn: 0.1345823	total: 2.69s	remaining: 14.6s
# 156:	learn: 0.1334656	total: 2.7s	remaining: 14.5s
# 157:	learn: 0.1322234	total: 2.71s	remaining: 14.4s
# 158:	learn: 0.1314709	total: 2.71s	remaining: 14.4s
# 159:	learn: 0.1304019	total: 2.72s	remaining: 14.3s
# 160:	learn: 0.1294764	total: 2.73s	remaining: 14.2s
# 161:	learn: 0.1290484	total: 2.73s	remaining: 14.1s
# 162:	learn: 0.1287505	total: 2.74s	remaining: 14.1s
# 163:	learn: 0.1275892	total: 2.75s	remaining: 14s
# 164:	learn: 0.1267860	total: 2.76s	remaining: 13.9s
# 165:	learn: 0.1259581	total: 2.76s	remaining: 13.9s
# 166:	learn: 0.1249259	total: 2.77s	remaining: 13.8s
# 167:	learn: 0.1236171	total: 2.78s	remaining: 13.8s
# 168:	learn: 0.1222879	total: 2.78s	remaining: 13.7s
# 169:	learn: 0.1218184	total: 2.79s	remaining: 13.6s
# 170:	learn: 0.1215138	total: 2.8s	remaining: 13.6s
# 171:	learn: 0.1204216	total: 2.81s	remaining: 13.5s
# 172:	learn: 0.1193154	total: 2.81s	remaining: 13.5s
# 173:	learn: 0.1185385	total: 2.83s	remaining: 13.4s
# 174:	learn: 0.1180199	total: 2.84s	remaining: 13.4s
# 175:	learn: 0.1168652	total: 2.85s	remaining: 13.3s
# 176:	learn: 0.1168113	total: 2.86s	remaining: 13.3s
# 177:	learn: 0.1164753	total: 2.87s	remaining: 13.2s
# 178:	learn: 0.1156625	total: 2.88s	remaining: 13.2s
# 179:	learn: 0.1145006	total: 2.9s	remaining: 13.2s
# 180:	learn: 0.1130797	total: 2.92s	remaining: 13.2s
# 181:	learn: 0.1128737	total: 2.93s	remaining: 13.2s
# 182:	learn: 0.1114708	total: 2.94s	remaining: 13.1s
# 183:	learn: 0.1103290	total: 2.94s	remaining: 13.1s
# 184:	learn: 0.1089581	total: 2.95s	remaining: 13s
# 185:	learn: 0.1079541	total: 2.96s	remaining: 12.9s
# 186:	learn: 0.1070862	total: 2.96s	remaining: 12.9s
# 187:	learn: 0.1068590	total: 2.97s	remaining: 12.8s
# 188:	learn: 0.1057251	total: 2.98s	remaining: 12.8s
# 189:	learn: 0.1050998	total: 2.99s	remaining: 12.7s
# 190:	learn: 0.1042360	total: 3s	remaining: 12.7s
# 191:	learn: 0.1027876	total: 3s	remaining: 12.6s
# 192:	learn: 0.1025839	total: 3.01s	remaining: 12.6s
# 193:	learn: 0.1014756	total: 3.02s	remaining: 12.6s
# 194:	learn: 0.1004641	total: 3.03s	remaining: 12.5s
# 195:	learn: 0.0995168	total: 3.04s	remaining: 12.5s
# 196:	learn: 0.0987184	total: 3.04s	remaining: 12.4s
# 197:	learn: 0.0979015	total: 3.06s	remaining: 12.4s
# 198:	learn: 0.0972207	total: 3.07s	remaining: 12.3s
# 199:	learn: 0.0962569	total: 3.08s	remaining: 12.3s
# 200:	learn: 0.0955238	total: 3.09s	remaining: 12.3s
# 201:	learn: 0.0947518	total: 3.1s	remaining: 12.2s
# 202:	learn: 0.0945489	total: 3.1s	remaining: 12.2s
# 203:	learn: 0.0936225	total: 3.11s	remaining: 12.1s
# 204:	learn: 0.0931764	total: 3.12s	remaining: 12.1s
# 205:	learn: 0.0929083	total: 3.13s	remaining: 12.1s
# 206:	learn: 0.0928146	total: 3.13s	remaining: 12s
# 207:	learn: 0.0919603	total: 3.14s	remaining: 12s
# 208:	learn: 0.0914324	total: 3.15s	remaining: 11.9s
# 209:	learn: 0.0913913	total: 3.15s	remaining: 11.9s
# 210:	learn: 0.0904167	total: 3.16s	remaining: 11.8s
# 211:	learn: 0.0896963	total: 3.17s	remaining: 11.8s
# 212:	learn: 0.0889206	total: 3.18s	remaining: 11.8s
# 213:	learn: 0.0884359	total: 3.19s	remaining: 11.7s
# 214:	learn: 0.0881248	total: 3.2s	remaining: 11.7s
# 215:	learn: 0.0879942	total: 3.21s	remaining: 11.6s
# 216:	learn: 0.0872618	total: 3.21s	remaining: 11.6s
# 217:	learn: 0.0864983	total: 3.22s	remaining: 11.6s
# 218:	learn: 0.0858650	total: 3.23s	remaining: 11.5s
# 219:	learn: 0.0852503	total: 3.23s	remaining: 11.5s
# 220:	learn: 0.0850647	total: 3.24s	remaining: 11.4s
# 221:	learn: 0.0842636	total: 3.25s	remaining: 11.4s
# 222:	learn: 0.0841879	total: 3.26s	remaining: 11.3s
# 223:	learn: 0.0836116	total: 3.26s	remaining: 11.3s
# 224:	learn: 0.0835142	total: 3.27s	remaining: 11.3s
# 225:	learn: 0.0830629	total: 3.29s	remaining: 11.3s
# 226:	learn: 0.0829537	total: 3.3s	remaining: 11.2s
# 227:	learn: 0.0823235	total: 3.32s	remaining: 11.2s
# 228:	learn: 0.0822492	total: 3.33s	remaining: 11.2s
# 229:	learn: 0.0816792	total: 3.34s	remaining: 11.2s
# 230:	learn: 0.0811796	total: 3.35s	remaining: 11.1s
# 231:	learn: 0.0806475	total: 3.35s	remaining: 11.1s
# 232:	learn: 0.0802379	total: 3.36s	remaining: 11.1s
# 233:	learn: 0.0799348	total: 3.37s	remaining: 11s
# 234:	learn: 0.0791787	total: 3.38s	remaining: 11s
# 235:	learn: 0.0789623	total: 3.38s	remaining: 10.9s
# 236:	learn: 0.0786731	total: 3.39s	remaining: 10.9s
# 237:	learn: 0.0778828	total: 3.4s	remaining: 10.9s
# 238:	learn: 0.0772610	total: 3.4s	remaining: 10.8s
# 239:	learn: 0.0763170	total: 3.41s	remaining: 10.8s
# 240:	learn: 0.0759463	total: 3.42s	remaining: 10.8s
# 241:	learn: 0.0752120	total: 3.42s	remaining: 10.7s
# 242:	learn: 0.0746768	total: 3.43s	remaining: 10.7s
# 243:	learn: 0.0746169	total: 3.44s	remaining: 10.7s
# 244:	learn: 0.0740451	total: 3.45s	remaining: 10.6s
# 245:	learn: 0.0735105	total: 3.46s	remaining: 10.6s
# 246:	learn: 0.0729435	total: 3.47s	remaining: 10.6s
# 247:	learn: 0.0723574	total: 3.48s	remaining: 10.5s
# 248:	learn: 0.0722972	total: 3.49s	remaining: 10.5s
# 249:	learn: 0.0717954	total: 3.49s	remaining: 10.5s
# 250:	learn: 0.0713910	total: 3.51s	remaining: 10.5s
# 251:	learn: 0.0710961	total: 3.52s	remaining: 10.4s
# 252:	learn: 0.0707448	total: 3.53s	remaining: 10.4s
# 253:	learn: 0.0701985	total: 3.54s	remaining: 10.4s
# 254:	learn: 0.0696595	total: 3.55s	remaining: 10.4s
# 255:	learn: 0.0691214	total: 3.56s	remaining: 10.3s
# 256:	learn: 0.0685674	total: 3.56s	remaining: 10.3s
# 257:	learn: 0.0682659	total: 3.57s	remaining: 10.3s
# 258:	learn: 0.0679605	total: 3.58s	remaining: 10.2s
# 259:	learn: 0.0675861	total: 3.59s	remaining: 10.2s
# 260:	learn: 0.0672993	total: 3.6s	remaining: 10.2s
# 261:	learn: 0.0670218	total: 3.6s	remaining: 10.2s
# 262:	learn: 0.0666552	total: 3.61s	remaining: 10.1s
# 263:	learn: 0.0660503	total: 3.62s	remaining: 10.1s
# 264:	learn: 0.0656591	total: 3.63s	remaining: 10.1s
# 265:	learn: 0.0654575	total: 3.63s	remaining: 10s
# 266:	learn: 0.0652394	total: 3.64s	remaining: 10s
# 267:	learn: 0.0646970	total: 3.65s	remaining: 9.97s
# 268:	learn: 0.0643828	total: 3.66s	remaining: 9.95s
# 269:	learn: 0.0639483	total: 3.67s	remaining: 9.93s
# 270:	learn: 0.0633921	total: 3.69s	remaining: 9.91s
# 271:	learn: 0.0633595	total: 3.71s	remaining: 9.92s
# 272:	learn: 0.0630393	total: 3.73s	remaining: 9.94s
# 273:	learn: 0.0627503	total: 3.75s	remaining: 9.94s
# 274:	learn: 0.0623995	total: 3.77s	remaining: 9.95s
# 275:	learn: 0.0622178	total: 3.79s	remaining: 9.94s
# 276:	learn: 0.0618038	total: 3.8s	remaining: 9.93s
# 277:	learn: 0.0612706	total: 3.81s	remaining: 9.9s
# 278:	learn: 0.0608783	total: 3.83s	remaining: 9.89s
# 279:	learn: 0.0604552	total: 3.84s	remaining: 9.88s
# 280:	learn: 0.0601317	total: 3.86s	remaining: 9.87s
# 281:	learn: 0.0600607	total: 3.87s	remaining: 9.85s
# 282:	learn: 0.0595467	total: 3.88s	remaining: 9.83s
# 283:	learn: 0.0593392	total: 3.89s	remaining: 9.81s
# 284:	learn: 0.0590650	total: 3.9s	remaining: 9.79s
# 285:	learn: 0.0589636	total: 3.91s	remaining: 9.76s
# 286:	learn: 0.0586515	total: 3.92s	remaining: 9.74s
# 287:	learn: 0.0582587	total: 3.93s	remaining: 9.71s
# 288:	learn: 0.0580660	total: 3.93s	remaining: 9.68s
# 289:	learn: 0.0573858	total: 3.95s	remaining: 9.67s
# 290:	learn: 0.0572236	total: 3.97s	remaining: 9.68s
# 291:	learn: 0.0566234	total: 3.98s	remaining: 9.66s
# 292:	learn: 0.0565798	total: 3.99s	remaining: 9.63s
# 293:	learn: 0.0561308	total: 4s	remaining: 9.6s
# 294:	learn: 0.0558877	total: 4s	remaining: 9.57s
# 295:	learn: 0.0556860	total: 4.01s	remaining: 9.54s
# 296:	learn: 0.0554224	total: 4.02s	remaining: 9.52s
# 297:	learn: 0.0551789	total: 4.03s	remaining: 9.49s
# 298:	learn: 0.0550169	total: 4.04s	remaining: 9.47s
# 299:	learn: 0.0546690	total: 4.05s	remaining: 9.45s
# 300:	learn: 0.0544456	total: 4.06s	remaining: 9.42s
# 301:	learn: 0.0542087	total: 4.07s	remaining: 9.4s
# 302:	learn: 0.0538304	total: 4.07s	remaining: 9.37s
# 303:	learn: 0.0537686	total: 4.08s	remaining: 9.34s
# 304:	learn: 0.0534748	total: 4.09s	remaining: 9.32s
# 305:	learn: 0.0533291	total: 4.1s	remaining: 9.3s
# 306:	learn: 0.0530660	total: 4.11s	remaining: 9.29s
# 307:	learn: 0.0530126	total: 4.14s	remaining: 9.31s
# 308:	learn: 0.0525060	total: 4.15s	remaining: 9.29s
# 309:	learn: 0.0524935	total: 4.17s	remaining: 9.27s
# 310:	learn: 0.0522505	total: 4.19s	remaining: 9.28s
# 311:	learn: 0.0519891	total: 4.21s	remaining: 9.29s
# 312:	learn: 0.0516768	total: 4.25s	remaining: 9.32s
# 313:	learn: 0.0513327	total: 4.26s	remaining: 9.3s
# 314:	learn: 0.0510569	total: 4.27s	remaining: 9.29s
# 315:	learn: 0.0509366	total: 4.28s	remaining: 9.26s
# 316:	learn: 0.0509027	total: 4.29s	remaining: 9.25s
# 317:	learn: 0.0504761	total: 4.31s	remaining: 9.24s
# 318:	learn: 0.0502186	total: 4.32s	remaining: 9.21s
# 319:	learn: 0.0500748	total: 4.33s	remaining: 9.2s
# 320:	learn: 0.0498093	total: 4.34s	remaining: 9.18s
# 321:	learn: 0.0495696	total: 4.35s	remaining: 9.16s
# 322:	learn: 0.0491610	total: 4.36s	remaining: 9.14s
# 323:	learn: 0.0490754	total: 4.37s	remaining: 9.13s
# 324:	learn: 0.0489251	total: 4.39s	remaining: 9.12s
# 325:	learn: 0.0486452	total: 4.41s	remaining: 9.11s
# 326:	learn: 0.0483309	total: 4.42s	remaining: 9.1s
# 327:	learn: 0.0480046	total: 4.43s	remaining: 9.08s
# 328:	learn: 0.0476475	total: 4.44s	remaining: 9.06s
# 329:	learn: 0.0472775	total: 4.45s	remaining: 9.04s
# 330:	learn: 0.0472250	total: 4.46s	remaining: 9.02s
# 331:	learn: 0.0469354	total: 4.47s	remaining: 8.99s
# 332:	learn: 0.0466937	total: 4.48s	remaining: 8.98s
# 333:	learn: 0.0466355	total: 4.49s	remaining: 8.96s
# 334:	learn: 0.0464934	total: 4.5s	remaining: 8.93s
# 335:	learn: 0.0462840	total: 4.51s	remaining: 8.91s
# 336:	learn: 0.0460256	total: 4.52s	remaining: 8.89s
# 337:	learn: 0.0457033	total: 4.53s	remaining: 8.87s
# 338:	learn: 0.0456109	total: 4.54s	remaining: 8.86s
# 339:	learn: 0.0452720	total: 4.55s	remaining: 8.83s
# 340:	learn: 0.0450469	total: 4.56s	remaining: 8.82s
# 341:	learn: 0.0448324	total: 4.57s	remaining: 8.79s
# 342:	learn: 0.0446278	total: 4.59s	remaining: 8.8s
# 343:	learn: 0.0443668	total: 4.61s	remaining: 8.8s
# 344:	learn: 0.0441761	total: 4.63s	remaining: 8.78s
# 345:	learn: 0.0439237	total: 4.64s	remaining: 8.78s
# 346:	learn: 0.0439169	total: 4.65s	remaining: 8.76s
# 347:	learn: 0.0435670	total: 4.66s	remaining: 8.73s
# 348:	learn: 0.0434127	total: 4.67s	remaining: 8.71s
# 349:	learn: 0.0431597	total: 4.68s	remaining: 8.69s
# 350:	learn: 0.0428088	total: 4.68s	remaining: 8.66s
# 351:	learn: 0.0427068	total: 4.7s	remaining: 8.65s
# 352:	learn: 0.0425197	total: 4.71s	remaining: 8.63s
# 353:	learn: 0.0423350	total: 4.72s	remaining: 8.61s
# 354:	learn: 0.0419276	total: 4.72s	remaining: 8.58s
# 355:	learn: 0.0417448	total: 4.73s	remaining: 8.56s
# 356:	learn: 0.0414929	total: 4.74s	remaining: 8.54s
# 357:	learn: 0.0411444	total: 4.75s	remaining: 8.52s
# 358:	learn: 0.0409931	total: 4.76s	remaining: 8.51s
# 359:	learn: 0.0409117	total: 4.78s	remaining: 8.49s
# 360:	learn: 0.0407150	total: 4.8s	remaining: 8.49s
# 361:	learn: 0.0405804	total: 4.81s	remaining: 8.48s
# 362:	learn: 0.0404384	total: 4.83s	remaining: 8.47s
# 363:	learn: 0.0402053	total: 4.84s	remaining: 8.46s
# 364:	learn: 0.0400615	total: 4.85s	remaining: 8.44s
# 365:	learn: 0.0398525	total: 4.86s	remaining: 8.41s
# 366:	learn: 0.0396877	total: 4.86s	remaining: 8.39s
# 367:	learn: 0.0394991	total: 4.87s	remaining: 8.37s
# 368:	learn: 0.0393620	total: 4.88s	remaining: 8.34s
# 369:	learn: 0.0392179	total: 4.89s	remaining: 8.32s
# 370:	learn: 0.0390267	total: 4.89s	remaining: 8.3s
# 371:	learn: 0.0387209	total: 4.91s	remaining: 8.28s
# 372:	learn: 0.0385003	total: 4.91s	remaining: 8.26s
# 373:	learn: 0.0382880	total: 4.92s	remaining: 8.24s
# 374:	learn: 0.0380306	total: 4.93s	remaining: 8.22s
# 375:	learn: 0.0379509	total: 4.94s	remaining: 8.2s
# 376:	learn: 0.0377243	total: 4.95s	remaining: 8.18s
# 377:	learn: 0.0374613	total: 4.96s	remaining: 8.16s
# 378:	learn: 0.0372486	total: 4.97s	remaining: 8.14s
# 379:	learn: 0.0371676	total: 4.97s	remaining: 8.11s
# 380:	learn: 0.0371122	total: 4.98s	remaining: 8.1s
# 381:	learn: 0.0369566	total: 4.99s	remaining: 8.07s
# 382:	learn: 0.0367666	total: 5s	remaining: 8.06s
# 383:	learn: 0.0366582	total: 5.02s	remaining: 8.05s
# 384:	learn: 0.0364884	total: 5.04s	remaining: 8.06s
# 385:	learn: 0.0362229	total: 5.06s	remaining: 8.06s
# 386:	learn: 0.0360760	total: 5.08s	remaining: 8.04s
# 387:	learn: 0.0360234	total: 5.08s	remaining: 8.02s
# 388:	learn: 0.0359064	total: 5.09s	remaining: 8s
# 389:	learn: 0.0356699	total: 5.1s	remaining: 7.98s
# 390:	learn: 0.0355598	total: 5.11s	remaining: 7.96s
# 391:	learn: 0.0354031	total: 5.12s	remaining: 7.95s
# 392:	learn: 0.0352883	total: 5.13s	remaining: 7.93s
# 393:	learn: 0.0352453	total: 5.15s	remaining: 7.92s
# 394:	learn: 0.0350641	total: 5.16s	remaining: 7.91s
# 395:	learn: 0.0349838	total: 5.17s	remaining: 7.89s
# 396:	learn: 0.0348412	total: 5.18s	remaining: 7.87s
# 397:	learn: 0.0346768	total: 5.19s	remaining: 7.85s
# 398:	learn: 0.0345500	total: 5.2s	remaining: 7.83s
# 399:	learn: 0.0344344	total: 5.21s	remaining: 7.81s
# 400:	learn: 0.0343508	total: 5.22s	remaining: 7.8s
# 401:	learn: 0.0342429	total: 5.23s	remaining: 7.79s
# 402:	learn: 0.0341402	total: 5.25s	remaining: 7.77s
# 403:	learn: 0.0340358	total: 5.25s	remaining: 7.75s
# 404:	learn: 0.0339745	total: 5.26s	remaining: 7.73s
# 405:	learn: 0.0339521	total: 5.27s	remaining: 7.71s
# 406:	learn: 0.0338381	total: 5.29s	remaining: 7.71s
# 407:	learn: 0.0336283	total: 5.3s	remaining: 7.69s
# 408:	learn: 0.0335167	total: 5.31s	remaining: 7.67s
# 409:	learn: 0.0333937	total: 5.32s	remaining: 7.66s
# 410:	learn: 0.0332270	total: 5.33s	remaining: 7.64s
# 411:	learn: 0.0330673	total: 5.34s	remaining: 7.62s
# 412:	learn: 0.0330340	total: 5.35s	remaining: 7.61s
# 413:	learn: 0.0329913	total: 5.36s	remaining: 7.58s
# 414:	learn: 0.0328376	total: 5.37s	remaining: 7.57s
# 415:	learn: 0.0326389	total: 5.38s	remaining: 7.54s
# 416:	learn: 0.0324984	total: 5.38s	remaining: 7.53s
# 417:	learn: 0.0323776	total: 5.39s	remaining: 7.5s
# 418:	learn: 0.0323624	total: 5.4s	remaining: 7.49s
# 419:	learn: 0.0321871	total: 5.41s	remaining: 7.47s
# 420:	learn: 0.0321558	total: 5.42s	remaining: 7.46s
# 421:	learn: 0.0320423	total: 5.44s	remaining: 7.45s
# 422:	learn: 0.0319401	total: 5.45s	remaining: 7.43s
# 423:	learn: 0.0319221	total: 5.46s	remaining: 7.41s
# 424:	learn: 0.0318394	total: 5.46s	remaining: 7.39s
# 425:	learn: 0.0318283	total: 5.47s	remaining: 7.37s
# 426:	learn: 0.0316017	total: 5.48s	remaining: 7.36s
# 427:	learn: 0.0313545	total: 5.49s	remaining: 7.33s
# 428:	learn: 0.0312699	total: 5.51s	remaining: 7.34s
# 429:	learn: 0.0311748	total: 5.53s	remaining: 7.33s
# 430:	learn: 0.0311593	total: 5.54s	remaining: 7.32s
# 431:	learn: 0.0311325	total: 5.56s	remaining: 7.31s
# 432:	learn: 0.0310954	total: 5.57s	remaining: 7.29s
# 433:	learn: 0.0309619	total: 5.62s	remaining: 7.33s
# 434:	learn: 0.0309049	total: 5.63s	remaining: 7.31s
# 435:	learn: 0.0307598	total: 5.65s	remaining: 7.3s
# 436:	learn: 0.0307584	total: 5.66s	remaining: 7.29s
# 437:	learn: 0.0306965	total: 5.68s	remaining: 7.29s
# 438:	learn: 0.0305845	total: 5.7s	remaining: 7.29s
# 439:	learn: 0.0305800	total: 5.72s	remaining: 7.28s
# 440:	learn: 0.0305143	total: 5.75s	remaining: 7.29s
# 441:	learn: 0.0303223	total: 5.77s	remaining: 7.28s
# 442:	learn: 0.0303106	total: 5.78s	remaining: 7.27s
# 443:	learn: 0.0301756	total: 5.8s	remaining: 7.26s
# 444:	learn: 0.0301683	total: 5.82s	remaining: 7.25s
# 445:	learn: 0.0301541	total: 5.87s	remaining: 7.29s
# 446:	learn: 0.0299816	total: 5.89s	remaining: 7.28s
# 447:	learn: 0.0298874	total: 5.9s	remaining: 7.27s
# 448:	learn: 0.0297675	total: 5.92s	remaining: 7.26s
# 449:	learn: 0.0295834	total: 5.93s	remaining: 7.24s
# 450:	learn: 0.0294658	total: 5.93s	remaining: 7.22s
# 451:	learn: 0.0293828	total: 5.94s	remaining: 7.2s
# 452:	learn: 0.0292584	total: 5.95s	remaining: 7.18s
# 453:	learn: 0.0291644	total: 5.96s	remaining: 7.16s
# 454:	learn: 0.0291599	total: 5.96s	remaining: 7.14s
# 455:	learn: 0.0289982	total: 5.97s	remaining: 7.12s
# 456:	learn: 0.0288777	total: 5.98s	remaining: 7.1s
# 457:	learn: 0.0287977	total: 5.98s	remaining: 7.08s
# 458:	learn: 0.0286658	total: 5.99s	remaining: 7.06s
# 459:	learn: 0.0286526	total: 6s	remaining: 7.04s
# 460:	learn: 0.0284901	total: 6.01s	remaining: 7.02s
# 461:	learn: 0.0283909	total: 6.01s	remaining: 7s
# 462:	learn: 0.0282316	total: 6.02s	remaining: 6.98s
# 463:	learn: 0.0281644	total: 6.03s	remaining: 6.96s
# 464:	learn: 0.0280631	total: 6.04s	remaining: 6.94s
# 465:	learn: 0.0280235	total: 6.04s	remaining: 6.92s
# 466:	learn: 0.0278815	total: 6.05s	remaining: 6.91s
# 467:	learn: 0.0277827	total: 6.06s	remaining: 6.88s
# 468:	learn: 0.0276758	total: 6.07s	remaining: 6.87s
# 469:	learn: 0.0275365	total: 6.08s	remaining: 6.86s
# 470:	learn: 0.0274590	total: 6.09s	remaining: 6.85s
# 471:	learn: 0.0272916	total: 6.12s	remaining: 6.84s
# 472:	learn: 0.0272384	total: 6.13s	remaining: 6.83s
# 473:	learn: 0.0271546	total: 6.14s	remaining: 6.82s
# 474:	learn: 0.0270594	total: 6.16s	remaining: 6.81s
# 475:	learn: 0.0268958	total: 6.17s	remaining: 6.79s
# 476:	learn: 0.0268936	total: 6.18s	remaining: 6.78s
# 477:	learn: 0.0268008	total: 6.2s	remaining: 6.77s
# 478:	learn: 0.0267299	total: 6.21s	remaining: 6.75s
# 479:	learn: 0.0266639	total: 6.21s	remaining: 6.73s
# 480:	learn: 0.0265262	total: 6.22s	remaining: 6.71s
# 481:	learn: 0.0264592	total: 6.23s	remaining: 6.7s
# 482:	learn: 0.0263077	total: 6.25s	remaining: 6.68s
# 483:	learn: 0.0263077	total: 6.25s	remaining: 6.67s
# 484:	learn: 0.0261278	total: 6.26s	remaining: 6.65s
# 485:	learn: 0.0260563	total: 6.27s	remaining: 6.63s
# 486:	learn: 0.0260160	total: 6.28s	remaining: 6.62s
# 487:	learn: 0.0258952	total: 6.3s	remaining: 6.61s
# 488:	learn: 0.0258032	total: 6.31s	remaining: 6.6s
# 489:	learn: 0.0256904	total: 6.33s	remaining: 6.58s
# 490:	learn: 0.0255985	total: 6.34s	remaining: 6.57s
# 491:	learn: 0.0254918	total: 6.34s	remaining: 6.55s
# 492:	learn: 0.0253452	total: 6.35s	remaining: 6.53s
# 493:	learn: 0.0252656	total: 6.36s	remaining: 6.51s
# 494:	learn: 0.0251472	total: 6.37s	remaining: 6.49s
# 495:	learn: 0.0250086	total: 6.37s	remaining: 6.47s
# 496:	learn: 0.0249210	total: 6.38s	remaining: 6.46s
# 497:	learn: 0.0249163	total: 6.39s	remaining: 6.44s
# 498:	learn: 0.0248749	total: 6.39s	remaining: 6.42s
# 499:	learn: 0.0248466	total: 6.4s	remaining: 6.4s
# 500:	learn: 0.0247963	total: 6.41s	remaining: 6.38s
# 501:	learn: 0.0246612	total: 6.42s	remaining: 6.36s
# 502:	learn: 0.0245059	total: 6.42s	remaining: 6.34s
# 503:	learn: 0.0244090	total: 6.43s	remaining: 6.33s
# 504:	learn: 0.0243937	total: 6.44s	remaining: 6.31s
# 505:	learn: 0.0243061	total: 6.44s	remaining: 6.29s
# 506:	learn: 0.0242450	total: 6.45s	remaining: 6.27s
# 507:	learn: 0.0241519	total: 6.46s	remaining: 6.25s
# 508:	learn: 0.0241516	total: 6.46s	remaining: 6.24s
# 509:	learn: 0.0240169	total: 6.47s	remaining: 6.22s
# 510:	learn: 0.0239201	total: 6.48s	remaining: 6.2s
# 511:	learn: 0.0238500	total: 6.49s	remaining: 6.19s
# 512:	learn: 0.0238115	total: 6.5s	remaining: 6.17s
# 513:	learn: 0.0236954	total: 6.52s	remaining: 6.16s
# 514:	learn: 0.0235672	total: 6.53s	remaining: 6.15s
# 515:	learn: 0.0234293	total: 6.54s	remaining: 6.13s
# 516:	learn: 0.0233367	total: 6.55s	remaining: 6.12s
# 517:	learn: 0.0232340	total: 6.55s	remaining: 6.1s
# 518:	learn: 0.0231997	total: 6.56s	remaining: 6.08s
# 519:	learn: 0.0230363	total: 6.57s	remaining: 6.06s
# 520:	learn: 0.0229511	total: 6.58s	remaining: 6.05s
# 521:	learn: 0.0229443	total: 6.58s	remaining: 6.03s
# 522:	learn: 0.0228412	total: 6.59s	remaining: 6.01s
# 523:	learn: 0.0227643	total: 6.6s	remaining: 5.99s
# 524:	learn: 0.0225886	total: 6.61s	remaining: 5.98s
# 525:	learn: 0.0224978	total: 6.61s	remaining: 5.96s
# 526:	learn: 0.0224976	total: 6.62s	remaining: 5.94s
# 527:	learn: 0.0224474	total: 6.63s	remaining: 5.92s
# 528:	learn: 0.0223080	total: 6.64s	remaining: 5.91s
# 529:	learn: 0.0222400	total: 6.65s	remaining: 5.89s
# 530:	learn: 0.0221646	total: 6.65s	remaining: 5.88s
# 531:	learn: 0.0221313	total: 6.66s	remaining: 5.86s
# 532:	learn: 0.0220101	total: 6.67s	remaining: 5.84s
# 533:	learn: 0.0219448	total: 6.68s	remaining: 5.83s
# 534:	learn: 0.0218587	total: 6.69s	remaining: 5.82s
# 535:	learn: 0.0217212	total: 6.7s	remaining: 5.8s
# 536:	learn: 0.0216732	total: 6.72s	remaining: 5.79s
# 537:	learn: 0.0215833	total: 6.72s	remaining: 5.77s
# 538:	learn: 0.0215307	total: 6.73s	remaining: 5.76s
# 539:	learn: 0.0215010	total: 6.74s	remaining: 5.74s
# 540:	learn: 0.0214377	total: 6.74s	remaining: 5.72s
# 541:	learn: 0.0213286	total: 6.75s	remaining: 5.7s
# 542:	learn: 0.0212497	total: 6.76s	remaining: 5.69s
# 543:	learn: 0.0211470	total: 6.76s	remaining: 5.67s
# 544:	learn: 0.0210921	total: 6.77s	remaining: 5.65s
# 545:	learn: 0.0210538	total: 6.78s	remaining: 5.64s
# 546:	learn: 0.0209827	total: 6.79s	remaining: 5.62s
# 547:	learn: 0.0209428	total: 6.79s	remaining: 5.6s
# 548:	learn: 0.0208760	total: 6.8s	remaining: 5.58s
# 549:	learn: 0.0207576	total: 6.81s	remaining: 5.57s
# 550:	learn: 0.0207574	total: 6.81s	remaining: 5.55s
# 551:	learn: 0.0206815	total: 6.82s	remaining: 5.53s
# 552:	learn: 0.0206174	total: 6.83s	remaining: 5.52s
# 553:	learn: 0.0204629	total: 6.83s	remaining: 5.5s
# 554:	learn: 0.0204495	total: 6.84s	remaining: 5.48s
# 555:	learn: 0.0204039	total: 6.84s	remaining: 5.47s
# 556:	learn: 0.0203564	total: 6.85s	remaining: 5.45s
# 557:	learn: 0.0202386	total: 6.86s	remaining: 5.43s
# 558:	learn: 0.0201627	total: 6.86s	remaining: 5.42s
# 559:	learn: 0.0201289	total: 6.87s	remaining: 5.4s
# 560:	learn: 0.0200832	total: 6.88s	remaining: 5.38s
# 561:	learn: 0.0200473	total: 6.89s	remaining: 5.37s
# 562:	learn: 0.0200027	total: 6.9s	remaining: 5.36s
# 563:	learn: 0.0199921	total: 6.91s	remaining: 5.34s
# 564:	learn: 0.0198902	total: 6.92s	remaining: 5.33s
# 565:	learn: 0.0198234	total: 6.94s	remaining: 5.32s
# 566:	learn: 0.0197281	total: 6.94s	remaining: 5.3s
# 567:	learn: 0.0196607	total: 6.95s	remaining: 5.29s
# 568:	learn: 0.0196132	total: 6.96s	remaining: 5.27s
# 569:	learn: 0.0195851	total: 6.97s	remaining: 5.25s
# 570:	learn: 0.0195304	total: 6.97s	remaining: 5.24s
# 571:	learn: 0.0194640	total: 6.98s	remaining: 5.22s
# 572:	learn: 0.0194019	total: 6.99s	remaining: 5.21s
# 573:	learn: 0.0193186	total: 7s	remaining: 5.2s
# 574:	learn: 0.0192329	total: 7.01s	remaining: 5.18s
# 575:	learn: 0.0191731	total: 7.04s	remaining: 5.18s
# 576:	learn: 0.0190862	total: 7.05s	remaining: 5.17s
# 577:	learn: 0.0190519	total: 7.07s	remaining: 5.16s
# 578:	learn: 0.0190055	total: 7.08s	remaining: 5.15s
# 579:	learn: 0.0189409	total: 7.11s	remaining: 5.14s
# 580:	learn: 0.0189332	total: 7.12s	remaining: 5.13s
# 581:	learn: 0.0189221	total: 7.13s	remaining: 5.13s
# 582:	learn: 0.0188777	total: 7.16s	remaining: 5.12s
# 583:	learn: 0.0188704	total: 7.18s	remaining: 5.12s
# 584:	learn: 0.0188329	total: 7.21s	remaining: 5.11s
# 585:	learn: 0.0188329	total: 7.22s	remaining: 5.1s
# 586:	learn: 0.0188079	total: 7.24s	remaining: 5.09s
# 587:	learn: 0.0187882	total: 7.26s	remaining: 5.08s
# 588:	learn: 0.0187309	total: 7.26s	remaining: 5.07s
# 589:	learn: 0.0186926	total: 7.27s	remaining: 5.05s
# 590:	learn: 0.0186776	total: 7.28s	remaining: 5.04s
# 591:	learn: 0.0185956	total: 7.28s	remaining: 5.02s
# 592:	learn: 0.0185619	total: 7.29s	remaining: 5s
# 593:	learn: 0.0185619	total: 7.3s	remaining: 4.99s
# 594:	learn: 0.0185490	total: 7.3s	remaining: 4.97s
# 595:	learn: 0.0185315	total: 7.32s	remaining: 4.96s
# 596:	learn: 0.0185038	total: 7.33s	remaining: 4.95s
# 597:	learn: 0.0184766	total: 7.34s	remaining: 4.93s
# 598:	learn: 0.0184710	total: 7.36s	remaining: 4.92s
# 599:	learn: 0.0184540	total: 7.36s	remaining: 4.91s
# 600:	learn: 0.0183293	total: 7.37s	remaining: 4.89s
# 601:	learn: 0.0182956	total: 7.38s	remaining: 4.88s
# 602:	learn: 0.0182746	total: 7.39s	remaining: 4.86s
# 603:	learn: 0.0182413	total: 7.39s	remaining: 4.85s
# 604:	learn: 0.0182318	total: 7.4s	remaining: 4.83s
# 605:	learn: 0.0181975	total: 7.41s	remaining: 4.82s
# 606:	learn: 0.0181562	total: 7.42s	remaining: 4.8s
# 607:	learn: 0.0180612	total: 7.42s	remaining: 4.79s
# 608:	learn: 0.0180611	total: 7.43s	remaining: 4.77s
# 609:	learn: 0.0180309	total: 7.44s	remaining: 4.75s
# 610:	learn: 0.0180242	total: 7.44s	remaining: 4.74s
# 611:	learn: 0.0179932	total: 7.45s	remaining: 4.72s
# 612:	learn: 0.0179543	total: 7.46s	remaining: 4.71s
# 613:	learn: 0.0179312	total: 7.46s	remaining: 4.69s
# 614:	learn: 0.0179254	total: 7.47s	remaining: 4.68s
# 615:	learn: 0.0179181	total: 7.48s	remaining: 4.66s
# 616:	learn: 0.0178797	total: 7.49s	remaining: 4.65s
# 617:	learn: 0.0177916	total: 7.49s	remaining: 4.63s
# 618:	learn: 0.0177694	total: 7.5s	remaining: 4.62s
# 619:	learn: 0.0177220	total: 7.51s	remaining: 4.6s
# 620:	learn: 0.0176764	total: 7.51s	remaining: 4.59s
# 621:	learn: 0.0176645	total: 7.53s	remaining: 4.58s
# 622:	learn: 0.0176404	total: 7.54s	remaining: 4.56s
# 623:	learn: 0.0175349	total: 7.55s	remaining: 4.55s
# 624:	learn: 0.0174521	total: 7.6s	remaining: 4.56s
# 625:	learn: 0.0174374	total: 7.77s	remaining: 4.64s
# 626:	learn: 0.0173578	total: 7.78s	remaining: 4.63s
# 627:	learn: 0.0173548	total: 7.81s	remaining: 4.62s
# 628:	learn: 0.0173142	total: 7.83s	remaining: 4.62s
# 629:	learn: 0.0172714	total: 7.85s	remaining: 4.61s
# 630:	learn: 0.0172278	total: 7.87s	remaining: 4.6s
# 631:	learn: 0.0171870	total: 7.89s	remaining: 4.59s
# 632:	learn: 0.0170862	total: 7.91s	remaining: 4.59s
# 633:	learn: 0.0170532	total: 7.93s	remaining: 4.58s
# 634:	learn: 0.0170017	total: 7.94s	remaining: 4.57s
# 635:	learn: 0.0169540	total: 7.96s	remaining: 4.55s
# 636:	learn: 0.0168938	total: 7.97s	remaining: 4.54s
# 637:	learn: 0.0168929	total: 7.99s	remaining: 4.53s
# 638:	learn: 0.0168589	total: 8s	remaining: 4.52s
# 639:	learn: 0.0167862	total: 8.01s	remaining: 4.5s
# 640:	learn: 0.0167861	total: 8.01s	remaining: 4.49s
# 641:	learn: 0.0167513	total: 8.02s	remaining: 4.47s
# 642:	learn: 0.0167457	total: 8.03s	remaining: 4.46s
# 643:	learn: 0.0166852	total: 8.05s	remaining: 4.45s
# 644:	learn: 0.0166359	total: 8.08s	remaining: 4.45s
# 645:	learn: 0.0165439	total: 8.24s	remaining: 4.51s
# 646:	learn: 0.0164987	total: 8.26s	remaining: 4.51s
# 647:	learn: 0.0164624	total: 8.29s	remaining: 4.5s
# 648:	learn: 0.0164622	total: 8.3s	remaining: 4.49s
# 649:	learn: 0.0164100	total: 8.33s	remaining: 4.49s
# 650:	learn: 0.0163086	total: 8.36s	remaining: 4.48s
# 651:	learn: 0.0162696	total: 8.38s	remaining: 4.47s
# 652:	learn: 0.0161868	total: 8.39s	remaining: 4.46s
# 653:	learn: 0.0161497	total: 8.41s	remaining: 4.45s
# 654:	learn: 0.0161376	total: 8.42s	remaining: 4.43s
# 655:	learn: 0.0161004	total: 8.44s	remaining: 4.42s
# 656:	learn: 0.0161004	total: 8.45s	remaining: 4.41s
# 657:	learn: 0.0160420	total: 8.48s	remaining: 4.41s
# 658:	learn: 0.0160100	total: 8.49s	remaining: 4.39s
# 659:	learn: 0.0159643	total: 8.5s	remaining: 4.38s
# 660:	learn: 0.0159029	total: 8.52s	remaining: 4.37s
# 661:	learn: 0.0158416	total: 8.52s	remaining: 4.35s
# 662:	learn: 0.0157736	total: 8.53s	remaining: 4.34s
# 663:	learn: 0.0157735	total: 8.54s	remaining: 4.32s
# 664:	learn: 0.0157669	total: 8.56s	remaining: 4.31s
# 665:	learn: 0.0157648	total: 8.57s	remaining: 4.3s
# 666:	learn: 0.0157309	total: 8.58s	remaining: 4.28s
# 667:	learn: 0.0156878	total: 8.59s	remaining: 4.27s
# 668:	learn: 0.0156486	total: 8.6s	remaining: 4.25s
# 669:	learn: 0.0156392	total: 8.61s	remaining: 4.24s
# 670:	learn: 0.0156372	total: 8.62s	remaining: 4.23s
# 671:	learn: 0.0156040	total: 8.63s	remaining: 4.21s
# 672:	learn: 0.0155492	total: 8.65s	remaining: 4.2s
# 673:	learn: 0.0154873	total: 8.67s	remaining: 4.19s
# 674:	learn: 0.0154507	total: 8.68s	remaining: 4.18s
# 675:	learn: 0.0154400	total: 8.7s	remaining: 4.17s
# 676:	learn: 0.0154160	total: 8.71s	remaining: 4.16s
# 677:	learn: 0.0153143	total: 8.73s	remaining: 4.14s
# 678:	learn: 0.0152858	total: 8.75s	remaining: 4.14s
# 679:	learn: 0.0152394	total: 8.76s	remaining: 4.12s
# 680:	learn: 0.0152394	total: 8.77s	remaining: 4.11s
# 681:	learn: 0.0152305	total: 8.78s	remaining: 4.09s
# 682:	learn: 0.0152298	total: 8.79s	remaining: 4.08s
# 683:	learn: 0.0152213	total: 8.79s	remaining: 4.06s
# 684:	learn: 0.0151630	total: 8.8s	remaining: 4.05s
# 685:	learn: 0.0151118	total: 8.81s	remaining: 4.03s
# 686:	learn: 0.0151101	total: 8.81s	remaining: 4.02s
# 687:	learn: 0.0150994	total: 8.82s	remaining: 4s
# 688:	learn: 0.0150939	total: 8.83s	remaining: 3.98s
# 689:	learn: 0.0150325	total: 8.84s	remaining: 3.97s
# 690:	learn: 0.0149552	total: 8.85s	remaining: 3.96s
# 691:	learn: 0.0149460	total: 8.85s	remaining: 3.94s
# 692:	learn: 0.0149459	total: 8.86s	remaining: 3.92s
# 693:	learn: 0.0149062	total: 8.87s	remaining: 3.91s
# 694:	learn: 0.0148892	total: 8.88s	remaining: 3.89s
# 695:	learn: 0.0148671	total: 8.88s	remaining: 3.88s
# 696:	learn: 0.0148612	total: 8.9s	remaining: 3.87s
# 697:	learn: 0.0148612	total: 8.91s	remaining: 3.85s
# 698:	learn: 0.0148135	total: 8.92s	remaining: 3.84s
# 699:	learn: 0.0147679	total: 8.93s	remaining: 3.83s
# 700:	learn: 0.0147549	total: 8.95s	remaining: 3.82s
# 701:	learn: 0.0147036	total: 8.96s	remaining: 3.8s
# 702:	learn: 0.0147036	total: 8.97s	remaining: 3.79s
# 703:	learn: 0.0146893	total: 8.98s	remaining: 3.78s
# 704:	learn: 0.0146357	total: 8.99s	remaining: 3.76s
# 705:	learn: 0.0146057	total: 9s	remaining: 3.75s
# 706:	learn: 0.0145673	total: 9.02s	remaining: 3.74s
# 707:	learn: 0.0145655	total: 9.03s	remaining: 3.72s
# 708:	learn: 0.0145373	total: 9.04s	remaining: 3.71s
# 709:	learn: 0.0145266	total: 9.05s	remaining: 3.7s
# 710:	learn: 0.0144884	total: 9.06s	remaining: 3.68s
# 711:	learn: 0.0144368	total: 9.08s	remaining: 3.67s
# 712:	learn: 0.0144125	total: 9.09s	remaining: 3.66s
# 713:	learn: 0.0144125	total: 9.1s	remaining: 3.65s
# 714:	learn: 0.0143970	total: 9.12s	remaining: 3.63s
# 715:	learn: 0.0143695	total: 9.13s	remaining: 3.62s
# 716:	learn: 0.0143324	total: 9.15s	remaining: 3.61s
# 717:	learn: 0.0143213	total: 9.19s	remaining: 3.61s
# 718:	learn: 0.0143033	total: 9.21s	remaining: 3.6s
# 719:	learn: 0.0143018	total: 9.23s	remaining: 3.59s
# 720:	learn: 0.0142599	total: 9.25s	remaining: 3.58s
# 721:	learn: 0.0142198	total: 9.28s	remaining: 3.57s
# 722:	learn: 0.0141896	total: 9.29s	remaining: 3.56s
# 723:	learn: 0.0141700	total: 9.31s	remaining: 3.55s
# 724:	learn: 0.0141113	total: 9.32s	remaining: 3.54s
# 725:	learn: 0.0140523	total: 9.33s	remaining: 3.52s
# 726:	learn: 0.0140473	total: 9.35s	remaining: 3.51s
# 727:	learn: 0.0140447	total: 9.36s	remaining: 3.5s
# 728:	learn: 0.0140231	total: 9.38s	remaining: 3.49s
# 729:	learn: 0.0140047	total: 9.39s	remaining: 3.47s
# 730:	learn: 0.0140047	total: 9.39s	remaining: 3.46s
# 731:	learn: 0.0139693	total: 9.4s	remaining: 3.44s
# 732:	learn: 0.0139498	total: 9.41s	remaining: 3.43s
# 733:	learn: 0.0139105	total: 9.42s	remaining: 3.41s
# 734:	learn: 0.0138337	total: 9.43s	remaining: 3.4s
# 735:	learn: 0.0138222	total: 9.44s	remaining: 3.38s
# 736:	learn: 0.0138222	total: 9.44s	remaining: 3.37s
# 737:	learn: 0.0137982	total: 9.45s	remaining: 3.35s
# 738:	learn: 0.0137982	total: 9.46s	remaining: 3.34s
# 739:	learn: 0.0137597	total: 9.47s	remaining: 3.33s
# 740:	learn: 0.0137288	total: 9.47s	remaining: 3.31s
# 741:	learn: 0.0136592	total: 9.49s	remaining: 3.3s
# 742:	learn: 0.0136026	total: 9.49s	remaining: 3.28s
# 743:	learn: 0.0136026	total: 9.5s	remaining: 3.27s
# 744:	learn: 0.0135720	total: 9.51s	remaining: 3.25s
# 745:	learn: 0.0135231	total: 9.52s	remaining: 3.24s
# 746:	learn: 0.0135042	total: 9.53s	remaining: 3.23s
# 747:	learn: 0.0134918	total: 9.54s	remaining: 3.21s
# 748:	learn: 0.0134587	total: 9.55s	remaining: 3.2s
# 749:	learn: 0.0134587	total: 9.57s	remaining: 3.19s
# 750:	learn: 0.0134342	total: 9.58s	remaining: 3.17s
# 751:	learn: 0.0134039	total: 9.59s	remaining: 3.16s
# 752:	learn: 0.0133699	total: 9.59s	remaining: 3.15s
# 753:	learn: 0.0133345	total: 9.6s	remaining: 3.13s
# 754:	learn: 0.0133157	total: 9.61s	remaining: 3.12s
# 755:	learn: 0.0132835	total: 9.62s	remaining: 3.1s
# 756:	learn: 0.0132625	total: 9.62s	remaining: 3.09s
# 757:	learn: 0.0132625	total: 9.63s	remaining: 3.07s
# 758:	learn: 0.0132502	total: 9.64s	remaining: 3.06s
# 759:	learn: 0.0132353	total: 9.64s	remaining: 3.05s
# 760:	learn: 0.0132051	total: 9.65s	remaining: 3.03s
# 761:	learn: 0.0131554	total: 9.66s	remaining: 3.02s
# 762:	learn: 0.0131416	total: 9.67s	remaining: 3s
# 763:	learn: 0.0131240	total: 9.68s	remaining: 2.99s
# 764:	learn: 0.0130770	total: 9.68s	remaining: 2.97s
# 765:	learn: 0.0130758	total: 9.69s	remaining: 2.96s
# 766:	learn: 0.0130468	total: 9.7s	remaining: 2.94s
# 767:	learn: 0.0130137	total: 9.7s	remaining: 2.93s
# 768:	learn: 0.0129722	total: 9.71s	remaining: 2.92s
# 769:	learn: 0.0129517	total: 9.72s	remaining: 2.9s
# 770:	learn: 0.0129257	total: 9.73s	remaining: 2.89s
# 771:	learn: 0.0129121	total: 9.75s	remaining: 2.88s
# 772:	learn: 0.0128779	total: 9.76s	remaining: 2.87s
# 773:	learn: 0.0128423	total: 9.77s	remaining: 2.85s
# 774:	learn: 0.0128386	total: 9.78s	remaining: 2.84s
# 775:	learn: 0.0128125	total: 9.8s	remaining: 2.83s
# 776:	learn: 0.0128125	total: 9.81s	remaining: 2.82s
# 777:	learn: 0.0127819	total: 9.83s	remaining: 2.8s
# 778:	learn: 0.0127569	total: 9.84s	remaining: 2.79s
# 779:	learn: 0.0127186	total: 9.85s	remaining: 2.78s
# 780:	learn: 0.0127033	total: 9.87s	remaining: 2.77s
# 781:	learn: 0.0126720	total: 9.89s	remaining: 2.76s
# 782:	learn: 0.0126360	total: 9.89s	remaining: 2.74s
# 783:	learn: 0.0126359	total: 9.9s	remaining: 2.73s
# 784:	learn: 0.0125886	total: 9.92s	remaining: 2.72s
# 785:	learn: 0.0125470	total: 9.93s	remaining: 2.7s
# 786:	learn: 0.0125054	total: 9.95s	remaining: 2.69s
# 787:	learn: 0.0125053	total: 9.96s	remaining: 2.68s
# 788:	learn: 0.0124716	total: 9.97s	remaining: 2.67s
# 789:	learn: 0.0124428	total: 9.98s	remaining: 2.65s
# 790:	learn: 0.0124428	total: 9.99s	remaining: 2.64s
# 791:	learn: 0.0124307	total: 10s	remaining: 2.63s
# 792:	learn: 0.0123964	total: 10s	remaining: 2.61s
# 793:	learn: 0.0123634	total: 10s	remaining: 2.6s
# 794:	learn: 0.0123634	total: 10s	remaining: 2.59s
# 795:	learn: 0.0123209	total: 10s	remaining: 2.57s
# 796:	learn: 0.0123210	total: 10s	remaining: 2.56s
# 797:	learn: 0.0122994	total: 10.1s	remaining: 2.54s
# 798:	learn: 0.0122860	total: 10.1s	remaining: 2.53s
# 799:	learn: 0.0122444	total: 10.1s	remaining: 2.52s
# 800:	learn: 0.0122249	total: 10.1s	remaining: 2.5s
# 801:	learn: 0.0122059	total: 10.1s	remaining: 2.49s
# 802:	learn: 0.0121960	total: 10.1s	remaining: 2.47s
# 803:	learn: 0.0121946	total: 10.1s	remaining: 2.46s
# 804:	learn: 0.0121526	total: 10.1s	remaining: 2.45s
# 805:	learn: 0.0121004	total: 10.1s	remaining: 2.43s
# 806:	learn: 0.0120767	total: 10.1s	remaining: 2.42s
# 807:	learn: 0.0120708	total: 10.1s	remaining: 2.4s
# 808:	learn: 0.0120567	total: 10.1s	remaining: 2.39s
# 809:	learn: 0.0120439	total: 10.1s	remaining: 2.38s
# 810:	learn: 0.0120439	total: 10.1s	remaining: 2.36s
# 811:	learn: 0.0120306	total: 10.2s	remaining: 2.35s
# 812:	learn: 0.0120305	total: 10.2s	remaining: 2.34s
# 813:	learn: 0.0120305	total: 10.2s	remaining: 2.33s
# 814:	learn: 0.0120234	total: 10.2s	remaining: 2.31s
# 815:	learn: 0.0120228	total: 10.2s	remaining: 2.3s
# 816:	learn: 0.0119863	total: 10.2s	remaining: 2.29s
# 817:	learn: 0.0119411	total: 10.2s	remaining: 2.27s
# 818:	learn: 0.0119391	total: 10.2s	remaining: 2.26s
# 819:	learn: 0.0119298	total: 10.2s	remaining: 2.25s
# 820:	learn: 0.0119298	total: 10.2s	remaining: 2.23s
# 821:	learn: 0.0118924	total: 10.3s	remaining: 2.22s
# 822:	learn: 0.0118513	total: 10.3s	remaining: 2.21s
# 823:	learn: 0.0118191	total: 10.3s	remaining: 2.19s
# 824:	learn: 0.0117971	total: 10.3s	remaining: 2.18s
# 825:	learn: 0.0117778	total: 10.3s	remaining: 2.17s
# 826:	learn: 0.0117581	total: 10.3s	remaining: 2.15s
# 827:	learn: 0.0117393	total: 10.3s	remaining: 2.14s
# 828:	learn: 0.0117248	total: 10.3s	remaining: 2.13s
# 829:	learn: 0.0117097	total: 10.3s	remaining: 2.12s
# 830:	learn: 0.0116871	total: 10.3s	remaining: 2.1s
# 831:	learn: 0.0116594	total: 10.4s	remaining: 2.09s
# 832:	learn: 0.0116455	total: 10.4s	remaining: 2.08s
# 833:	learn: 0.0116325	total: 10.4s	remaining: 2.07s
# 834:	learn: 0.0116112	total: 10.4s	remaining: 2.06s
# 835:	learn: 0.0116106	total: 10.4s	remaining: 2.04s
# 836:	learn: 0.0115725	total: 10.4s	remaining: 2.03s
# 837:	learn: 0.0115531	total: 10.4s	remaining: 2.02s
# 838:	learn: 0.0115526	total: 10.5s	remaining: 2.01s
# 839:	learn: 0.0115427	total: 10.5s	remaining: 1.99s
# 840:	learn: 0.0115427	total: 10.5s	remaining: 1.98s
# 841:	learn: 0.0115264	total: 10.5s	remaining: 1.97s
# 842:	learn: 0.0115264	total: 10.5s	remaining: 1.95s
# 843:	learn: 0.0115263	total: 10.5s	remaining: 1.94s
# 844:	learn: 0.0114984	total: 10.5s	remaining: 1.93s
# 845:	learn: 0.0114984	total: 10.5s	remaining: 1.91s
# 846:	learn: 0.0114575	total: 10.5s	remaining: 1.9s
# 847:	learn: 0.0114500	total: 10.5s	remaining: 1.89s
# 848:	learn: 0.0114143	total: 10.5s	remaining: 1.87s
# 849:	learn: 0.0114008	total: 10.5s	remaining: 1.86s
# 850:	learn: 0.0113691	total: 10.6s	remaining: 1.85s
# 851:	learn: 0.0113241	total: 10.6s	remaining: 1.84s
# 852:	learn: 0.0113031	total: 10.6s	remaining: 1.82s
# 853:	learn: 0.0112775	total: 10.6s	remaining: 1.81s
# 854:	learn: 0.0112631	total: 10.6s	remaining: 1.8s
# 855:	learn: 0.0112288	total: 10.6s	remaining: 1.78s
# 856:	learn: 0.0112287	total: 10.6s	remaining: 1.77s
# 857:	learn: 0.0112287	total: 10.6s	remaining: 1.76s
# 858:	learn: 0.0112287	total: 10.6s	remaining: 1.75s
# 859:	learn: 0.0112067	total: 10.6s	remaining: 1.73s
# 860:	learn: 0.0111999	total: 10.7s	remaining: 1.72s
# 861:	learn: 0.0111712	total: 10.7s	remaining: 1.71s
# 862:	learn: 0.0111489	total: 10.7s	remaining: 1.69s
# 863:	learn: 0.0111253	total: 10.7s	remaining: 1.68s
# 864:	learn: 0.0111023	total: 10.7s	remaining: 1.67s
# 865:	learn: 0.0111022	total: 10.7s	remaining: 1.65s
# 866:	learn: 0.0111022	total: 10.7s	remaining: 1.64s
# 867:	learn: 0.0110890	total: 10.7s	remaining: 1.63s
# 868:	learn: 0.0110832	total: 10.7s	remaining: 1.61s
# 869:	learn: 0.0110761	total: 10.7s	remaining: 1.6s
# 870:	learn: 0.0110517	total: 10.7s	remaining: 1.59s
# 871:	learn: 0.0110418	total: 10.7s	remaining: 1.57s
# 872:	learn: 0.0110260	total: 10.7s	remaining: 1.56s
# 873:	learn: 0.0110260	total: 10.8s	remaining: 1.55s
# 874:	learn: 0.0109951	total: 10.8s	remaining: 1.54s
# 875:	learn: 0.0109869	total: 10.8s	remaining: 1.53s
# 876:	learn: 0.0109700	total: 10.8s	remaining: 1.51s
# 877:	learn: 0.0109655	total: 10.8s	remaining: 1.5s
# 878:	learn: 0.0109480	total: 10.8s	remaining: 1.49s
# 879:	learn: 0.0109480	total: 10.8s	remaining: 1.48s
# 880:	learn: 0.0109206	total: 10.8s	remaining: 1.46s
# 881:	learn: 0.0108760	total: 10.8s	remaining: 1.45s
# 882:	learn: 0.0108632	total: 10.8s	remaining: 1.44s
# 883:	learn: 0.0108507	total: 10.9s	remaining: 1.42s
# 884:	learn: 0.0108499	total: 10.9s	remaining: 1.41s
# 885:	learn: 0.0108437	total: 10.9s	remaining: 1.4s
# 886:	learn: 0.0108434	total: 10.9s	remaining: 1.39s
# 887:	learn: 0.0108433	total: 10.9s	remaining: 1.37s
# 888:	learn: 0.0108433	total: 10.9s	remaining: 1.36s
# 889:	learn: 0.0108255	total: 10.9s	remaining: 1.35s
# 890:	learn: 0.0108254	total: 10.9s	remaining: 1.33s
# 891:	learn: 0.0108253	total: 10.9s	remaining: 1.32s
# 892:	learn: 0.0107952	total: 10.9s	remaining: 1.31s
# 893:	learn: 0.0107674	total: 10.9s	remaining: 1.29s
# 894:	learn: 0.0107360	total: 10.9s	remaining: 1.28s
# 895:	learn: 0.0107029	total: 10.9s	remaining: 1.27s
# 896:	learn: 0.0107029	total: 10.9s	remaining: 1.26s
# 897:	learn: 0.0107029	total: 10.9s	remaining: 1.24s
# 898:	learn: 0.0106785	total: 11s	remaining: 1.23s
# 899:	learn: 0.0106785	total: 11s	remaining: 1.22s
# 900:	learn: 0.0106785	total: 11s	remaining: 1.2s
# 901:	learn: 0.0106785	total: 11s	remaining: 1.19s
# 902:	learn: 0.0106604	total: 11s	remaining: 1.18s
# 903:	learn: 0.0106515	total: 11s	remaining: 1.17s
# 904:	learn: 0.0106514	total: 11s	remaining: 1.16s
# 905:	learn: 0.0106514	total: 11s	remaining: 1.14s
# 906:	learn: 0.0106124	total: 11s	remaining: 1.13s
# 907:	learn: 0.0105686	total: 11s	remaining: 1.12s
# 908:	learn: 0.0105682	total: 11s	remaining: 1.1s
# 909:	learn: 0.0105682	total: 11s	remaining: 1.09s
# 910:	learn: 0.0105681	total: 11.1s	remaining: 1.08s
# 911:	learn: 0.0105619	total: 11.1s	remaining: 1.07s
# 912:	learn: 0.0105341	total: 11.1s	remaining: 1.05s
# 913:	learn: 0.0105267	total: 11.1s	remaining: 1.04s
# 914:	learn: 0.0105267	total: 11.1s	remaining: 1.03s
# 915:	learn: 0.0105264	total: 11.1s	remaining: 1.02s
# 916:	learn: 0.0105264	total: 11.1s	remaining: 1s
# 917:	learn: 0.0105263	total: 11.1s	remaining: 991ms
# 918:	learn: 0.0104820	total: 11.1s	remaining: 979ms
# 919:	learn: 0.0104680	total: 11.1s	remaining: 967ms
# 920:	learn: 0.0104680	total: 11.1s	remaining: 955ms
# 921:	learn: 0.0104561	total: 11.1s	remaining: 943ms
# 922:	learn: 0.0104228	total: 11.2s	remaining: 930ms
# 923:	learn: 0.0104039	total: 11.2s	remaining: 918ms
# 924:	learn: 0.0103971	total: 11.2s	remaining: 906ms
# 925:	learn: 0.0103971	total: 11.2s	remaining: 894ms
# 926:	learn: 0.0103883	total: 11.2s	remaining: 882ms
# 927:	learn: 0.0103802	total: 11.2s	remaining: 869ms
# 928:	learn: 0.0103629	total: 11.2s	remaining: 858ms
# 929:	learn: 0.0103544	total: 11.2s	remaining: 845ms
# 930:	learn: 0.0103451	total: 11.2s	remaining: 833ms
# 931:	learn: 0.0103136	total: 11.2s	remaining: 821ms
# 932:	learn: 0.0102794	total: 11.3s	remaining: 808ms
# 933:	learn: 0.0102794	total: 11.3s	remaining: 796ms
# 934:	learn: 0.0102611	total: 11.3s	remaining: 783ms
# 935:	learn: 0.0102611	total: 11.3s	remaining: 771ms
# 936:	learn: 0.0102453	total: 11.3s	remaining: 759ms
# 937:	learn: 0.0101925	total: 11.3s	remaining: 746ms
# 938:	learn: 0.0101558	total: 11.3s	remaining: 734ms
# 939:	learn: 0.0101296	total: 11.3s	remaining: 721ms
# 940:	learn: 0.0101105	total: 11.3s	remaining: 709ms
# 941:	learn: 0.0100924	total: 11.3s	remaining: 697ms
# 942:	learn: 0.0100547	total: 11.3s	remaining: 684ms
# 943:	learn: 0.0100547	total: 11.3s	remaining: 672ms
# 944:	learn: 0.0100387	total: 11.3s	remaining: 660ms
# 945:	learn: 0.0100081	total: 11.3s	remaining: 647ms
# 946:	learn: 0.0100081	total: 11.3s	remaining: 635ms
# 947:	learn: 0.0100081	total: 11.4s	remaining: 623ms
# 948:	learn: 0.0100081	total: 11.4s	remaining: 611ms
# 949:	learn: 0.0100079	total: 11.4s	remaining: 598ms
# 950:	learn: 0.0099996	total: 11.4s	remaining: 586ms
# 951:	learn: 0.0099996	total: 11.4s	remaining: 574ms
# 952:	learn: 0.0099996	total: 11.4s	remaining: 562ms
# 953:	learn: 0.0099996	total: 11.4s	remaining: 550ms
# 954:	learn: 0.0099838	total: 11.4s	remaining: 538ms
# 955:	learn: 0.0099838	total: 11.4s	remaining: 526ms
# 956:	learn: 0.0099784	total: 11.4s	remaining: 514ms
# 957:	learn: 0.0099424	total: 11.5s	remaining: 502ms
# 958:	learn: 0.0099424	total: 11.5s	remaining: 490ms
# 959:	learn: 0.0099282	total: 11.5s	remaining: 478ms
# 960:	learn: 0.0099061	total: 11.5s	remaining: 466ms
# 961:	learn: 0.0098779	total: 11.5s	remaining: 454ms
# 962:	learn: 0.0098778	total: 11.5s	remaining: 442ms
# 963:	learn: 0.0098549	total: 11.5s	remaining: 430ms
# 964:	learn: 0.0098281	total: 11.5s	remaining: 417ms
# 965:	learn: 0.0097965	total: 11.5s	remaining: 405ms
# 966:	learn: 0.0097827	total: 11.5s	remaining: 393ms
# 967:	learn: 0.0097827	total: 11.5s	remaining: 381ms
# 968:	learn: 0.0097598	total: 11.5s	remaining: 369ms
# 969:	learn: 0.0097597	total: 11.5s	remaining: 357ms
# 970:	learn: 0.0097597	total: 11.5s	remaining: 345ms
# 971:	learn: 0.0097448	total: 11.6s	remaining: 333ms
# 972:	learn: 0.0097287	total: 11.6s	remaining: 321ms
# 973:	learn: 0.0097287	total: 11.6s	remaining: 309ms
# 974:	learn: 0.0097164	total: 11.6s	remaining: 297ms
# 975:	learn: 0.0097026	total: 11.6s	remaining: 285ms
# 976:	learn: 0.0096662	total: 11.6s	remaining: 273ms
# 977:	learn: 0.0096662	total: 11.6s	remaining: 261ms
# 978:	learn: 0.0096661	total: 11.6s	remaining: 249ms
# 979:	learn: 0.0096397	total: 11.6s	remaining: 238ms
# 980:	learn: 0.0096168	total: 11.7s	remaining: 226ms
# 981:	learn: 0.0096168	total: 11.7s	remaining: 214ms
# 982:	learn: 0.0096025	total: 11.7s	remaining: 202ms
# 983:	learn: 0.0095836	total: 11.7s	remaining: 190ms
# 984:	learn: 0.0095836	total: 11.7s	remaining: 178ms
# 985:	learn: 0.0095714	total: 11.7s	remaining: 166ms
# 986:	learn: 0.0095269	total: 11.7s	remaining: 155ms
# 987:	learn: 0.0095036	total: 11.8s	remaining: 143ms
# 988:	learn: 0.0094934	total: 11.8s	remaining: 131ms
# 989:	learn: 0.0094748	total: 11.8s	remaining: 119ms
# 990:	learn: 0.0094748	total: 11.8s	remaining: 107ms
# 991:	learn: 0.0094635	total: 11.8s	remaining: 95.2ms
# 992:	learn: 0.0094558	total: 11.8s	remaining: 83.4ms
# 993:	learn: 0.0094250	total: 11.8s	remaining: 71.4ms
# 994:	learn: 0.0093962	total: 11.8s	remaining: 59.5ms
# 995:	learn: 0.0093961	total: 11.9s	remaining: 47.6ms
# 996:	learn: 0.0093712	total: 11.9s	remaining: 35.7ms
# 997:	learn: 0.0093678	total: 11.9s	remaining: 23.8ms
# 998:	learn: 0.0093605	total: 11.9s	remaining: 11.9ms
# 999:	learn: 0.0093605	total: 11.9s	remaining: 0us
# Accuracy: 81.97278911564626

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[ 99  29]
#  [ 24 142]]

# %%
from sklearn.ensemble import AdaBoostClassifier

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Initialize the AdaBoost classifier
adaboost = AdaBoostClassifier(n_estimators=50, random_state=42)

# Train the model
adaboost.fit(X_train, y_train)

# Predictions on the test set
y_pred = adaboost.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy*100)

# Classification report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 75.51020408163265
#               precision    recall  f1-score   support
#
#            0       0.70      0.71      0.70       121
#            1       0.80      0.79      0.79       173
#
#     accuracy                           0.76       294
#    macro avg       0.75      0.75      0.75       294
# weighted avg       0.76      0.76      0.76       294

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[ 86  35]
#  [ 37 136]]

# %%
from sklearn.tree import DecisionTreeClassifier
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled,
                                                test_size=0.2, random_state=42)

# Initialize the Decision Tree classifier
decision_tree = DecisionTreeClassifier(random_state=42)
# Train the model
decision_tree.fit(X_train, y_train)
# Predictions on the test set
y_pred = decision_tree.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Decision Tree Accuracy:", accuracy*100)

# Classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Decision Tree Accuracy: 78.91156462585033
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.78      0.75       121
#            1       0.84      0.80      0.82       173
#
#     accuracy                           0.79       294
#    macro avg       0.78      0.79      0.78       294
# weighted avg       0.79      0.79      0.79       294

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[ 94  27]
#  [ 35 138]]

# %%
from sklearn.ensemble import RandomForestClassifier
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, 
                                                test_size=0.2, random_state=42)

# Initialize the Random Forest classifier
random_forest = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
random_forest.fit(X_train, y_train)
# Predictions on the test set
y_pred = random_forest.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Random Forest Accuracy:", accuracy*100)

# Classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Random Forest Accuracy: 81.63265306122449
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78       121
#            1       0.85      0.84      0.84       173
#
#     accuracy                           0.82       294
#    macro avg       0.81      0.81      0.81       294
# weighted avg       0.82      0.82      0.82       294

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[ 95  26]
#  [ 28 145]]

# %%
from xgboost import XGBClassifier
# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled,
                                            test_size=0.2, random_state=42)

# Initialize XGBoost classifier
model = XGBClassifier()
# Train the classifier
model.fit(X_train, y_train)
# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy*100)
# Classification report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 85.37414965986395
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82       121
#            1       0.87      0.88      0.88       173
#
#     accuracy                           0.85       294
#    macro avg       0.85      0.85      0.85       294
# weighted avg       0.85      0.85      0.85       294

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[ 98  23]
#  [ 20 153]]

# %%
import lightgbm as lgb
# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, 
                                                    test_size=0.2, random_state=42)
# Define LightGBM parameters
params = {
    'objective': 'multiclass',
    'num_class': len(y.unique()),  # Number of classes
    'metric': 'multi_error'  # Error rate for multiclass classification
}
# Convert dataset to LightGBM format
train_data = lgb.Dataset(X_train, label=y_train)
test_data = lgb.Dataset(X_test, label=y_test)

# Train the LightGBM model
model = lgb.train(params, train_set=train_data, num_boost_round=100, valid_sets=[test_data])
# Make predictions
y_pred = model.predict(X_test)
y_pred_class = np.argmax(y_pred, axis=1)  # Get the index of the maximum value along the row axis

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred_class)
print("Accuracy:", accuracy*100)

# Classification report
print(classification_report(y_test, y_pred_class))
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001069 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1375
# [LightGBM] [Info] Number of data points in the train set: 1175, number of used features: 14
# [LightGBM] [Info] Start training from score -0.759105
# [LightGBM] [Info] Start training from score -0.631272
# Accuracy: 86.39455782312925
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83       121
#            1       0.87      0.91      0.89       173
#
#     accuracy                           0.86       294
#    macro avg       0.86      0.85      0.86       294
# weighted avg       0.86      0.86      0.86       294

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred_class)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[ 97  24]
#  [ 16 157]]
